# %%
# import some helpful python packages 
import numpy as np

from astropy.table import Table
from astropy.convolution import convolve, Gaussian1DKernel

import matplotlib 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import pandas as pd

# %matplotlib inline

# %%
# DESI targeting masks - 
from desitarget.sv1 import sv1_targetmask    # For SV1
from desitarget.sv2 import sv2_targetmask    # For SV2
from desitarget.sv3 import sv3_targetmask
from desitarget import __version__ as desitarget_version
from desitarget.targetmask import desi_mask

## DataLab related modules
from sparcl.client import SparclClient
from dl import queryClient as qc, authClient as ac

# %%
## Making the matplotlib plots look nicer
settings = {
    'font.size':22,
    'axes.linewidth':3.0,
    'xtick.major.size':6.0,
    'xtick.minor.size':4.0,
    'xtick.major.width':3.0,
    'xtick.minor.width':1.5,
    'xtick.direction':'in', 
    'xtick.minor.visible':True,
    'xtick.top':True,
    'ytick.major.size':6.0,
    'ytick.minor.size':4.0,
    'ytick.major.width':3.0,
    'ytick.minor.width':1.5,
    'ytick.direction':'in', 
    'ytick.minor.visible':True,
    'ytick.right':True
}

plt.rcParams.update(**settings)

# %%
## Load SPARCLClient
client = SparclClient()

# %%
print(qc.schema('desi_edr'))
# Out:
# Schema: desi_edr
#
#       Table Name   Description
#       ----------   -----------
#         exposure   Summary quantities for every DESI exposure
#      fiberassign   Quantities obtained when a DESI target is assigned to a fiber
#            frame   Summary quantities for each petal of the DESI instrument i
#                    n a given exposure; in normal operation there are ten fram
#                    es for every exposure
#       photometry   Photometric quantities from LS DR9 for every TARGETID
#        potential   For a given tile, this table lists all targets that could
#                    have received a fiber assignment
#           target   The quantities obtained when photometric objects are analy
#                    zed in the target selection process
#             tile   Summary quantities for every DESI tile (pointing on the sky)
# x1p5__zpix__allwise__source   desi_edr.zpix and xmatch_std.allwise__source crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__gaia_dr3__gaia_source   desi_edr.zpix and xmatch_std.gaia_dr3__gaia_source crossma
#                    tch (1.5 arcsec)
# x1p5__zpix__nsc_dr2__object   desi_edr.zpix and xmatch_std.nsc_dr2__object crossmatch (1
#                    .5 arcsec)
# x1p5__zpix__sdss_dr17__specobj   desi_edr.zpix and xmatch_std.sdss_dr17__specobj crossmatch
#                    (1.5 arcsec)
# x1p5__zpix__unwise_dr1__object   desi_edr.zpix and xmatch_std.unwise_dr1__object crossmatch
#                    (1.5 arcsec)
#             zpix   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by HEALPixel
#            ztile   Redshift and other quantities for spectra that have been g
#                    rouped and coadded by tile

# %%
## Columns in the zpix table
print(qc.schema('desi_edr.zpix'))
# Out:
# Schema: desi_edr
#  Table: zpix
#
#      Column Name   Description
#      -----------   -----------
#                z   Redshift measured by Redrock
#             zerr   Redshift error from Redrock
#             chi2   Best fit chi squared
#          coeff_0   Redrock template coefficients
#          coeff_1   Redrock template coefficients
#          coeff_2   Redrock template coefficients
#          coeff_3   Redrock template coefficients
#          coeff_4   Redrock template coefficients
#          coeff_5   Redrock template coefficients
#          coeff_6   Redrock template coefficients
#          coeff_7   Redrock template coefficients
#          coeff_8   Redrock template coefficients
#          coeff_9   Redrock template coefficients
#        deltachi2   Delta-chi-squared for template fit from Redrock
#    mean_fiber_ra   Mean (over exposures) RA of actual fiber position
#   mean_fiber_dec   Mean (over exposures) DEC of actual fiber position
#             elon   Ecliptic longitude
#             elat   Ecliptic latitude
#             glon   Galactic longitude
#             glat   Galactic latitude
#               id   Arbitrary primary key composed from targetid, survey, program
#         targetid   Unique DESI target ID
#    coadd_exptime   Sum of the exposure times contributing to the coadd for th
#                    is target
#     mean_delta_x   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 X location on focal plane
#      rms_delta_x   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 X location on focal plane
#     mean_delta_y   Mean (over exposures) fiber difference between measured an
#                    d requested CS5 Y location on focal plane
#      rms_delta_y   RMS (over exposures) of the fiber difference between measu
#                    red and requested CS5 Y location on focal plane
#     std_fiber_ra   Standard deviation (over exposures) of RA of actual fiber
#                    position
#    std_fiber_dec   Standard deviation (over exposures) of DEC of actual fiber
#                    position
# mean_psf_to_fiber_specflux   Mean of the PSF_TO_FIBER_SPECFLUX values of the spectra us
#                    ed in the coadd
#  tsnr2_gpbdark_b   GPBDARK B template (S/N)^2
#      tsnr2_elg_b   ELG B template (S/N)^2
# tsnr2_gpbbright_b   GPBBRIGHT B template (S/N)^2
#      tsnr2_lya_b   LYA B template (S/N)^2
#      tsnr2_bgs_b   BGS B template (S/N)^2
# tsnr2_gpbbackup_b   GPBBACKUP B template (S/N)^2
#      tsnr2_qso_b   QSO B template (S/N)^2
#      tsnr2_lrg_b   LRG B template (S/N)^2
#  tsnr2_gpbdark_r   GPBDARK R template (S/N)^2
#      tsnr2_elg_r   ELG R template (S/N)^2
# tsnr2_gpbbright_r   GPBBRIGHT R template (S/N)^2
#      tsnr2_lya_r   LYA R template (S/N)^2
#      tsnr2_bgs_r   BGS R template (S/N)^2
# tsnr2_gpbbackup_r   GPBBACKUP R template (S/N)^2
#      tsnr2_qso_r   QSO R template (S/N)^2
#      tsnr2_lrg_r   LRG R template (S/N)^2
#  tsnr2_gpbdark_z   GPBDARK Z template (S/N)^2
#      tsnr2_elg_z   ELG Z template (S/N)^2
# tsnr2_gpbbright_z   GPBBRIGHT Z template (S/N)^2
#      tsnr2_lya_z   LYA Z template (S/N)^2
#      tsnr2_bgs_z   BGS Z template (S/N)^2
# tsnr2_gpbbackup_z   GPBBACKUP Z template (S/N)^2
#      tsnr2_qso_z   QSO Z template (S/N)^2
#      tsnr2_lrg_z   LRG Z template (S/N)^2
#    tsnr2_gpbdark   GPBDARK template (S/N)^2 summed over B, R, Z
#        tsnr2_elg   ELG template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbright   GPBBRIGHT template (S/N)^2 summed over B, R, Z
#        tsnr2_lya   LYA template (S/N)^2 summed over B, R, Z
#        tsnr2_bgs   BGS template (S/N)^2 summed over B, R, Z
#  tsnr2_gpbbackup   GPBBACKUP template (S/N)^2 summed over B, R, Z
#        tsnr2_qso   QSO template (S/N)^2 summed over B, R, Z
#        tsnr2_lrg   LRG template (S/N)^2 summed over B, R, Z
#        random_id   Random ID in the range 0.0 => 100.0 (not unique)
#         spgrpval   Value corresponding to the grouping type indicated in the
#                    spgrp column. For zpix table this is the same as the healp
#                    ix column
#          healpix   HEALPixel containing this location at NSIDE=64 in the NEST
#                    ED scheme
# coadd_fiberstatus   Bitwise AND of the FIBERSTATUS values of the spectra used
#                    in the coadd
#             htm9   Ninth level (~10 arcmin resolution) Hierarchical Triangula
#                    r Mesh index (Szalay et al. 2007)
#          ring256   Ring-scheme HEALPix (Gorski et al. 2005) index with Nsides
#                    =256 (~14 arcmin size)
#         nest4096   Nested-scheme HEALPix (Gorski et al. 2005) index with Nsid
#                    es=4096 (~52 arcsec size)
#            zwarn   Redshift warning bitmask measured by Redrock
#          npixels   Number of unmasked wavelengths that contributed to the red
#                    shift fit
#           ncoeff   Number of Redrock template coefficients
#     coadd_numexp   Number of exposures included in the coadd for this target
#   coadd_numnight   Number of different nights included in the coadd for this
#                    target
#    coadd_numtile   Number of different tiles included in the coadd for this target
#         sv_nspec   Number of coadded spectra for this TARGETID in SV (SV1+2+3)
#       main_nspec   Number of coadded spectra for this TARGETID in Main survey
#       zcat_nspec   Number of coadded spectra for this TARGETID in this zcatalog
#       sv_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in SV (SV1+2+3)
#     main_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in Main survey
#     zcat_primary   Boolean flag (True/False) for the primary coadded spectrum
#                    in this zcatalog
#            spgrp   Type of spectral grouping. For zpix table this is always =
#                    healpix
#          subtype   Spectral subtype
#          program   DESI program type - BRIGHT, DARK, or BACKUP
#         spectype   Spectype from Redrock file
#           survey   Survey name
#       firstnight   KPNO Calendar Date for the first NIGHT of observation coad
#                    ded into the spectrum
#        lastnight   KPNO Calendar Date for the last NIGHT of the last observat
#                    ion coadded into the spectrum
#         mean_mjd   Mean (over exposures) of the Modified Julian Date (MJD) wh
#                    en the shutter was opened
#          min_mjd   Minimum value of the Modified Julian Date (when the shutte
#                    r was open for the first exposure)
#          max_mjd   Maximum value of the Modified Julian Date (when the shutte
#                    r was open for the last exposure, i.e. not including the e
#                    xposure time)
#       mws_target   Milky Way Survey targeting bits
#   sv1_mws_target   MWS (bright time program) target selection bitmask for SV1
#   sv2_mws_target   MWS (bright time program) target selection bitmask for SV2
#   sv3_mws_target   MWS (bright time program) target selection bitmask for SV3
#      scnd_target   Target selection bitmask for secondary programs
#  sv1_scnd_target   Secondary target selection bitmask for SV1
#  sv2_scnd_target   Secondary target selection bitmask for SV2
#  sv3_scnd_target   Secondary target selection bitmask for SV3
#       bgs_target   BGS (bright time program) target selection bitmask
#   sv1_bgs_target   BGS (bright time program) target selection bitmask for SV1
#   sv2_bgs_target   BGS (bright time program) target selection bitmask for SV2
#   sv3_bgs_target   BGS (bright time program) target selection bitmask for SV3
#      desi_target   Dark survey + calibration targeting bits
#  sv1_desi_target   DESI (dark time program) target selection bitmask for SV1
#  sv2_desi_target   DESI (dark time program) target selection bitmask for SV2
#  sv3_desi_target   DESI (dark time program) target selection bitmask for SV3
#       cmx_target   Target selection bitmask for commissioning

# %%
query = """
SELECT zp.targetid, zp.survey, zp.program, zp.healpix,  
       zp.z, zp.zwarn, zp.coadd_fiberstatus, zp.spectype, 
       zp.mean_fiber_ra, zp.mean_fiber_dec, zp.zcat_nspec, 
       CAST(zp.zcat_primary AS INT), zp.desi_target,
       zp.sv1_desi_target, zp.sv2_desi_target, zp.sv3_desi_target
FROM desi_edr.zpix AS zp
""" 

## Information about the query
## Selected columns --
## targetid, survey, program -- unique identifiers for a given spectrum
## healpix -- healpix number for the target
## z -- spectroscopic redshift of the target
## zwarn -- encoded information regarding the redshift (zwarn = 0 is good)
## coadd_fiberstatus -- encoded information regarding the fiber that is assigned to the target (coadd_fiberstatus = 0 is good)
## spectype -- Spectral type of the target: STAR | GALAXY | QSO
## mean_fiber_ra, mean_fiber_dec -- Mean R.A. and Dec. of the fiber position from all the observations of the target
## zcat_nspec -- Number of coadded spectra that are available for a given target
## zcat_primary -- Whether or not a given coadded spectra is the primary spectra. ZCAT_PRIMARY = True for the "best" spectrum.
## CASTing this column as an INT: ZCAT_PRIMARY = 1 for the "best" spectrum.
## desi_target -- encodeds main survey's desi targeting information - explained in detail below
## sv1_desi_target -- encodes sv1 desi targeting information
## sv2_desi_target -- encodes sv2 desi targeting information
## sv3_desi_target -- encodes sv3 desi targeting information

# %%
print(query)
# Out:
# SELECT zp.targetid, zp.survey, zp.program, zp.healpix,
#        zp.z, zp.zwarn, zp.coadd_fiberstatus, zp.spectype,
#        zp.mean_fiber_ra, zp.mean_fiber_dec, zp.zcat_nspec,
#        CAST(zp.zcat_primary AS INT), zp.desi_target,
#        zp.sv1_desi_target, zp.sv2_desi_target, zp.sv3_desi_target
# FROM desi_edr.zpix AS zp

# %%
# %%time
zpix = qc.query(sql = query, fmt = 'pandas')
# Out:
# CPU times: user 2.92 s, sys: 1.93 s, total: 4.86 s
# Wall time: 38.2 s

# %%
print(f"The resulting table has {len(zpix)} rows")
zpix[0:5]
# Out:
# The resulting table has 2044588 rows
#             targetid survey program  healpix         z  zwarn  \
# 0  39633405607936686    sv3    dark    15340  0.349208      0
# 1  39633405607936686    sv3  bright    15340  0.349182      0
# 2  39633405607936462    sv3  bright    15340 -0.000327      0
# 3  39633405607936221    sv3  bright    15340 -0.000064      0
# 4  39633405603746754    sv3  bright    15340  0.262433      0
#
#    coadd_fiberstatus spectype  mean_fiber_ra  mean_fiber_dec  zcat_nspec  \
# 0                  0      QSO      272.41810       61.551533           2
# 1                  0      QSO      272.41812       61.551567           2
# 2                  0     STAR      272.39273       61.551990           1
# 3                  0     STAR      272.36700       61.496170           1
# 4                  0   GALAXY      272.34732       61.499382           1
#
#    zcat_primary  desi_target  sv1_desi_target  sv2_desi_target  \
# 0             1            0                0                0
# 1             0            0                0                0
# 2             1            0                0                0
# 3             1            0                0                0
# 4             1            0                0                0
#
#        sv3_desi_target
# 0  1152921504606855433
# 1  1152921504606855433
# 2  2305843009213693952
# 3  2305843009213693952
# 4  1152921504606846976

# %%
# Check how many rows have unique TARGETIDs before/after applying the ZCAT_PRIMARY flag
print(f"Total N(rows) : {len(zpix)}")
print(f"N(rows) with unique TARGETIDs : {len(np.unique(zpix['targetid']))}")

is_primary = zpix['zcat_primary']==1

print(f"N(rows) with ZCAT_PRIMARY=True : {len(zpix[is_primary])}")
# Out:
# Total N(rows) : 2044588
# N(rows) with unique TARGETIDs : 1979269
# N(rows) with ZCAT_PRIMARY=True : 1979269

# %%
## Selecting only unique objects
zpix_cat = zpix[is_primary]

# %%
# Targeting bits are coded in the sv*_targetmask.desi_mask
sv1_targetmask.desi_mask
# Out:
# sv1_desi_mask:
#   - [LRG,              0, "LRG", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3200, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3200, 'MORE_ZGOOD': 3200}, 'numobs': 2}]
#   - [ELG,              1, "ELG", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 3000, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3000, 'MORE_ZGOOD': 3000}, 'numobs': 1}]
#   - [QSO,              2, "QSO", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 4}]
#   - [LRG_OPT,          3, "LRG from baseline version of optical cuts", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3200, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3200, 'MORE_ZGOOD': 3200}, 'numobs': 4}]
#   - [LRG_IR,           4, "LRG from baseline version of IR cuts", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3200, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3200, 'MORE_ZGOOD': 3200}, 'numobs': 4}]
#   - [LRG_SV_OPT,       5, "LRG from relaxed version of optical cuts", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3200, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3200, 'MORE_ZGOOD': 3200}, 'numobs': 4}]
#   - [LRG_SV_IR,        6, "LRG from relaxed version of IR cuts", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3200, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3200, 'MORE_ZGOOD': 3200}, 'numobs': 4}]
#   - [LOWZ_FILLER,      7, "LRG-like low-z filler sample (NOT used for SV1)", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 10, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 10, 'MORE_ZGOOD': 10}, 'numobs': 1}]
#   - [ELG_SV_GTOT,      8, "ELG from relaxed version of FDR cuts and g-limit", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 3000, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3000, 'MORE_ZGOOD': 3000}, 'numobs': 1}]
#   - [ELG_SV_GFIB,      9, "ELG from relaxed version of FDR cuts and g-fiber-limit", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 3000, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3000, 'MORE_ZGOOD': 3000}, 'numobs': 1}]
#   - [ELG_FDR_GTOT,    10, "ELG from FDR cuts with g-mag-limit", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 3000, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3000, 'MORE_ZGOOD': 3000}, 'numobs': 1}]
#   - [ELG_FDR_GFIB,    11, "ELG from FDR cuts with g-fiber-mag-limit", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 3000, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 3000, 'MORE_ZGOOD': 3000}, 'numobs': 1}]
#   - [QSO_COLOR_4PASS, 12, "Low-z (tracer) QSO using color cuts", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 4}]
#   - [QSO_RF_4PASS,    13, "Low-z (tracer) QSO using random forest", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 4}]
#   - [QSO_COLOR_8PASS, 14, "High-z (Lyman-Alpha) QSO using color cuts", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 8}]
#   - [QSO_RF_8PASS,    15, "High-z (Lyman-Alpha) QSO using random forest", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 8}]
#   - [QSO_HZ_F,        16, "QSO at high-redshift and faint", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 4}]
#   - [QSO_Z5,          17, "z~5 QSO", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 3400, 'MORE_ZGOOD': 3350, 'MORE_ZWARN': 3300, 'MORE_MIDZQSO': 100, 'DONE': 2, 'OBS': 1, 'DONOTOBSERVE': 0}, 'numobs': 4}]
#   - [LRG_OPT_NORTH,   18, "LRG from baseline version of optical cuts tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_IR_NORTH,    19, "LRG from baseline version of IR cuts tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_SV_OPT_NORTH, 20, "LRG from relaxed version of optical cuts tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_SV_IR_NORTH, 21, "LRG from relaxed version of IR cuts tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LOWZ_FILLER_NORTH, 22, "LRG-like low-z filler sample tuned for Bok/Mosaic (NOT used for SV1)", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_OPT_SOUTH,   23, "LRG from baseline version of optical cuts tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_IR_SOUTH,    24, "LRG from baseline version of IR cuts tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_SV_OPT_SOUTH, 25, "LRG from relaxed version of optical cuts tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LRG_SV_IR_SOUTH, 26, "LRG from relaxed version of IR cuts tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [LOWZ_FILLER_SOUTH, 27, "LRG-like low-z filler sample tuned for DECam (NOT used for SV1)", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_SV_GTOT_NORTH, 28, "ELG from relaxed version of FDR cuts and g-limit for Bok/Mosaic", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_SV_GFIB_NORTH, 29, "ELG from relaxed version of FDR cuts and g-fiber-limit for Bok/Mosaic", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_FDR_GTOT_NORTH, 30, "ELG from FDR cuts with g-mag-limit for Bok/Mosaic", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_FDR_GFIB_NORTH, 31, "ELG from FDR cuts with g-fiber-mag-limit for Bok/Mosaic", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [SKY,             32, "Blank sky locations", {'obsconditions': 'DARK|GRAY|BRIGHT|BACKUP|TWILIGHT12|TWILIGHT18', 'priorities': {}, 'numobs': -1}]
#   - [STD_FAINT,       33, "Standard stars for dark/gray conditions", {'obsconditions': 'DARK|GRAY', 'priorities': {}, 'numobs': -1}]
#   - [STD_WD,          34, "White Dwarf stars", {'obsconditions': 'DARK|GRAY|BRIGHT', 'priorities': {}, 'numobs': -1}]
#   - [STD_BRIGHT,      35, "Standard stars for BRIGHT conditions", {'obsconditions': 'BRIGHT', 'priorities': {}, 'numobs': -1}]
#   - [BAD_SKY,         36, "Blank sky locations that are imperfect but still useable", {'obsconditions': 'DARK|GRAY|BRIGHT|BACKUP|TWILIGHT12|TWILIGHT18', 'priorities': {'UNOBS': 0, 'OBS': 0, 'DONE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0, 'DONOTOBSERVE': 1}, 'numobs': 0}]
#   - [SUPP_SKY,        37, "SKY is based on Gaia-avoidance (SKY will be set, too)", {'obsconditions': 'DARK|GRAY|BRIGHT|BACKUP|TWILIGHT12|TWILIGHT18', 'priorities': {}, 'numobs': -1}]
#   - [ELG_SV_GTOT_SOUTH, 38, "ELG from relaxed version of FDR cuts and g-limit for DECam", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_SV_GFIB_SOUTH, 39, "ELG from relaxed version of FDR cuts and g-fiber-limit for DECam", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_FDR_GTOT_SOUTH, 40, "ELG from FDR cuts with g-mag-limit for DECam", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [ELG_FDR_GFIB_SOUTH, 41, "ELG from FDR cuts with g-fiber-mag-limit for DECam", {'obsconditions': 'DARK|GRAY', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_COLOR_4PASS_NORTH, 42, "Low-z (tracer) QSO using color cuts tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_RF_4PASS_NORTH, 43, "Low-z (tracer) QSO using random forest tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_COLOR_8PASS_NORTH, 44, "High-z (Lyman-Alpha) QSO using color cuts tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_RF_8PASS_NORTH, 45, "High-z (Lyman-Alpha) QSO using random forest tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_HZ_F_NORTH,  46, "QSO at high-redshift and faint tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_Z5_NORTH,    47, "z~5 QSO tuned for Bok/Mosaic", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_COLOR_4PASS_SOUTH, 48, "Low-z (tracer) QSO using color cuts tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [NO_TARGET,       49, "No known target at this location", {'obsconditions': 'DARK|GRAY|BRIGHT|BACKUP|TWILIGHT12|TWILIGHT18', 'priorities': {}, 'numobs': -1}]
#   - [BRIGHT_OBJECT,   50, "Known bright object to avoid", {'obsconditions': 'APOCALYPSE', 'priorities': {}, 'numobs': -1}]
#   - [IN_BRIGHT_OBJECT, 51, "Too near a bright object; DO NOT OBSERVE", {'obsconditions': 'APOCALYPSE', 'priorities': {}, 'numobs': -1}]
#   - [NEAR_BRIGHT_OBJECT, 52, "Near a bright object but ok to observe", {'obsconditions': 'DARK|GRAY|BRIGHT|BACKUP|TWILIGHT12|TWILIGHT18', 'priorities': {}, 'numobs': -1}]
#   - [QSO_RF_4PASS_SOUTH, 53, "Low-z (tracer) QSO using random forest tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_COLOR_8PASS_SOUTH, 54, "High-z (Lyman-Alpha) QSO using color cuts tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_RF_8PASS_SOUTH, 55, "High-z (Lyman-Alpha) QSO using random forest tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_HZ_F_SOUTH,  56, "QSO at high-redshift and faint tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [QSO_Z5_SOUTH,    57, "z~5 QSO tuned for DECam", {'obsconditions': 'DARK', 'priorities': {'UNOBS': 0, 'DONE': 0, 'OBS': 0, 'DONOTOBSERVE': 0, 'MORE_ZWARN': 0, 'MORE_ZGOOD': 0}, 'numobs': 0}]
#   - [BGS_ANY,         60, "Any BGS bit is set", {'obsconditions': 'BRIGHT', 'priorities': {}, 'numobs': -1}]
#   - [MWS_ANY,         61, "Any MWS bit is set", {'obsconditions': 'BRIGHT', 'priorities': {}, 'numobs': -1}]
#   - [SCND_ANY,        62, "Any secondary bit is set", {'obsconditions': 'DARK|GRAY|BRIGHT|BACKUP|TWILIGHT12|TWILIGHT18', 'priorities': {}, 'numobs': -1}]

# %%
# A few example bitmask values

print(sv1_targetmask.desi_mask.mask("STD_BRIGHT"), sv1_targetmask.desi_mask.mask("STD_BRIGHT"), sv1_targetmask.desi_mask.mask("STD_FAINT|STD_BRIGHT"))
print(2**33, 2**35, 2**33 + 2**35)
# Out:
# 34359738368 34359738368 42949672960
# 8589934592 34359738368 42949672960

# %%
# Targeting information about the DESI targetting is stored in the different desi_target columns
# sv1_targetmask.desi_mask corresponds to SV1_DESI_TARGET
# sv2_targetmask.desi_mask corresponds to SV2_DESI_TARGET
# sv3_targetmask.desi_mask corresponds to SV3_DESI_TARGET

sv1_desi_tgt = zpix_cat['sv1_desi_target']
sv2_desi_tgt = zpix_cat['sv2_desi_target']
sv3_desi_tgt = zpix_cat['sv3_desi_target']

## DESI Bitmasks
sv1_desi_mask = sv1_targetmask.desi_mask
sv2_desi_mask = sv2_targetmask.desi_mask
sv3_desi_mask = sv3_targetmask.desi_mask

# %%
# Selecting candidates - 

is_bgs = (sv1_desi_tgt & sv1_desi_mask['BGS_ANY'] != 0)|(sv2_desi_tgt & sv2_desi_mask['BGS_ANY'] != 0)|(sv3_desi_tgt & sv3_desi_mask['BGS_ANY'] != 0)
is_lrg = (sv1_desi_tgt & sv1_desi_mask['LRG'] != 0)|(sv2_desi_tgt & sv2_desi_mask['LRG'] != 0)|(sv3_desi_tgt & sv3_desi_mask['LRG'] != 0)
is_elg = (sv1_desi_tgt & sv1_desi_mask['ELG'] != 0)|(sv2_desi_tgt & sv2_desi_mask['ELG'] != 0)|(sv3_desi_tgt & sv3_desi_mask['ELG'] != 0)
is_qso = (sv1_desi_tgt & sv1_desi_mask['QSO'] != 0)|(sv2_desi_tgt & sv2_desi_mask['QSO'] != 0)|(sv3_desi_tgt & sv3_desi_mask['QSO'] != 0)
is_mws = (sv1_desi_tgt & sv1_desi_mask['MWS_ANY'] != 0)|(sv2_desi_tgt & sv2_desi_mask['MWS_ANY'] != 0)|(sv3_desi_tgt & sv3_desi_mask['MWS_ANY'] != 0)
is_scnd = (sv1_desi_tgt & sv1_desi_mask['SCND_ANY'] != 0)|(sv2_desi_tgt & sv2_desi_mask['SCND_ANY'] != 0)|(sv3_desi_tgt & sv3_desi_mask['SCND_ANY'] != 0)

# %%
elg = zpix_cat[is_elg]

# %%
# created a mask to only show the galaxies within the ELG query. Which removes the QSO that are marked

mask2 = (elg['spectype'].values == 'GALAXY')&(elg['z']<=1.5)&(elg['z']>0.5)
new_elg_sample = elg.loc[mask2]
new_elg_sample
# Out:
#                   targetid survey program  healpix         z  zwarn  \
# 6        39633405603746559    sv3    dark    15342  0.961473      0
# 14       39633405603746334    sv3    dark    15342  0.951931      0
# 20       39633405603746163    sv3    dark    15342  0.921096      0
# 21       39633405603746462    sv3    dark    15342  0.955582      0
# 23       39633405603746272    sv3    dark    15342  0.930189      0
# ...                    ...    ...     ...      ...       ...    ...
# 2044568  39633405603744176    sv3    dark    15342  0.987729      0
# 2044574  39633405603744208    sv3    dark    15342  0.866510      0
# 2044580  39633405607936603    sv3    dark    15340  1.203081      0
# 2044581  39633405607936395    sv3    dark    15340  0.866633      0
# 2044585  39633405607936929    sv3    dark    15340  1.080380      0
#
#          coadd_fiberstatus spectype  mean_fiber_ra  mean_fiber_dec  \
# 6                        0   GALAXY      272.32507       61.504490
# 14                       0   GALAXY      272.29752       61.524826
# 20                       0   GALAXY      272.27725       61.533394
# 21                       0   GALAXY      272.31247       61.544907
# 23                       0   GALAXY      272.29004       61.562393
# ...                    ...      ...            ...             ...
# 2044568                  0   GALAXY      272.06897       61.446934
# 2044574                  0   GALAXY      272.07297       61.479330
# 2044580                  0   GALAXY      272.40820       61.479816
# 2044581                  0   GALAXY      272.38680       61.505800
# 2044585                  0   GALAXY      272.43887       61.552807
#
#          zcat_nspec  zcat_primary  desi_target  sv1_desi_target  \
# 6                 1             1            0                0
# 14                1             1            0                0
# 20                1             1            0                0
# 21                1             1            0                0
# 23                1             1            0                0
# ...             ...           ...          ...              ...
# 2044568           1             1            0                0
# 2044574           1             1            0                0
# 2044580           1             1            0                0
# 2044581           1             1            0                0
# 2044585           1             1            0                0
#
#          sv2_desi_target  sv3_desi_target
# 6                      0             4674
# 14                     0             4674
# 20                     0             4674
# 21                     0             4674
# 23                     0             2594
# ...                  ...              ...
# 2044568                0             4674
# 2044574                0             4674
# 2044580                0             4674
# 2044581                0             5702
# 2044585                0             4674
#
# [416469 rows x 16 columns]

# %%
# distribution of ELG Sample after the filtering

plt.hist(new_elg_sample['z'], bins = 'auto')
plt.ylabel('N(z)')
plt.xlabel('Redshift')
# Out:
# Text(0.5, 0, 'Redshift')

# %%
## Select QSO with nspec > 3 (nspec is just the number of available spectra)

jj = (zpix_cat['zcat_nspec'] >= 1)&(zpix_cat['spectype'] == 'QSO')&(zpix_cat['z']<=1.8)&(zpix_cat['z']>=0.5)
QSO_spec = zpix_cat[jj]

# %%
# Just plotting the table

QSO_spec
# Out:
#                   targetid survey program  healpix         z  zwarn  \
# 70       39633405603745713    sv3    dark    15342  1.715298      0
# 95       39633405603744805    sv3    dark    15342  1.122442      0
# 147      39633408485232706    sv3    dark    15342  1.722571      0
# 196      39633408485231664    sv3    dark    15342  1.141079      0
# 276      39633405603742091    sv3    dark    15342  1.209063      0
# ...                    ...    ...     ...      ...       ...    ...
# 2044130  39633408489424884    sv3    dark    15340  1.320221      0
# 2044251  39633411349939388    sv3    dark    15341  1.424983      4
# 2044409  39633405607936612    sv3    dark    15340  1.220517      4
# 2044451  39633405603746303    sv3    dark    15342  1.537800      0
# 2044526  39633405603745099    sv3    dark    15342  1.733955      0
#
#          coadd_fiberstatus spectype  mean_fiber_ra  mean_fiber_dec  \
# 70                       0      QSO      272.23080       61.482063
# 95                       0      QSO      272.13710       61.484110
# 147                      0      QSO      272.24265       61.639970
# 196                      0      QSO      272.14100       61.655495
# 276                      0      QSO      271.86185       61.380653
# ...                    ...      ...            ...             ...
# 2044130                  0      QSO      272.55590       61.738316
# 2044251                  0      QSO      272.76210       61.948357
# 2044409                  0      QSO      272.40915       61.390984
# 2044451                  0      QSO      272.29376       61.424680
# 2044526                  0      QSO      272.16684       61.422802
#
#          zcat_nspec  zcat_primary  desi_target  sv1_desi_target  \
# 70                1             1            0                0
# 95                1             1            0                0
# 147               1             1            0                0
# 196               1             1            0                0
# 276               1             1            0                0
# ...             ...           ...          ...              ...
# 2044130           1             1            0                0
# 2044251           1             1            0                0
# 2044409           1             1            0                0
# 2044451           1             1            0                0
# 2044526           1             1            0                0
#
#          sv2_desi_target      sv3_desi_target
# 70                     0                 1028
# 95                     0                 1028
# 147                    0  4611686018427393606
# 196                    0  4611686018427393606
# 276                    0                 5702
# ...                  ...                  ...
# 2044130                0                 1028
# 2044251                0  4611686018427388932
# 2044409                0  4611686018427391526
# 2044451                0                 5702
# 2044526                0  4611686018427393606
#
# [45382 rows x 16 columns]

# %%
# distribution of ELG Sample after the filtering

plt.hist(QSO_spec['z'], bins = 'auto')
plt.ylabel('N(z)')
plt.xlabel('Redshift')
# Out:
# Text(0.5, 0, 'Redshift')

# %%
new_dist = QSO_spec.sample(frac = .1)

# %%
len(new_dist)
# Out:
# 4538

# %%
# distribution of ELG Sample after the filtering

plt.hist(new_dist['z'], bins = 'auto')
plt.ylabel('N(z)')
plt.xlabel('Redshift')
# Out:
# Text(0.5, 0, 'Redshift')

# %%
new_dist_elg = new_elg_sample.sample(frac = .1)

# %%
len(new_dist_elg)
# Out:
# 41647

# %%
frames = [new_dist_elg, new_dist]

# %%
new_frame = pd.concat(frames
         )

# %%
plt.hist(new_frame['z'], bins = 'auto', label = 'elg')
# Out:
# (array([ 346.,  340.,  304.,  222.,  225.,  253.,  284.,  327.,  410.,
#          486.,  707.,  847., 1022., 1194., 1180., 1296., 1392., 1437.,
#         1451., 1508., 1495., 1711., 1517., 1434., 1249., 1263., 1282.,
#         1189., 1112., 1115., 1132., 1140., 1107., 1115., 1070.,  966.,
#          955., 1025., 1019., 1037.,  921.,  936.,  802.,  810.,  870.,
#          912.,  262.,  121.,  113.,  107.,  104.,  116.,  121.,  136.,
#          102.,  120.,  107.,  125.,  120.,  116.]),
#  array([0.50001623, 0.52168056, 0.5433449 , 0.56500923, 0.58667356,
#         0.60833789, 0.63000222, 0.65166655, 0.67333088, 0.69499522,
#         0.71665955, 0.73832388, 0.75998821, 0.78165254, 0.80331687,
#         0.8249812 , 0.84664554, 0.86830987, 0.8899742 , 0.91163853,
#         0.93330286, 0.95496719, 0.97663152, 0.99829585, 1.01996019,
#         1.04162452, 1.06328885, 1.08495318, 1.10661751, 1.12828184,
#         1.14994617, 1.17161051, 1.19327484, 1.21493917, 1.2366035 ,
#         1.25826783, 1.27993216, 1.30159649, 1.32326083, 1.34492516,
#         1.36658949, 1.38825382, 1.40991815, 1.43158248, 1.45324681,
#         1.47491114, 1.49657548, 1.51823981, 1.53990414, 1.56156847,
#         1.5832328 , 1.60489713, 1.62656146, 1.6482258 , 1.66989013,
#         1.69155446, 1.71321879, 1.73488312, 1.75654745, 1.77821178,
#         1.79987612]),
#  <BarContainer object of 60 artists>)

# %%
plt.hist(new_dist['z'], bins = 'auto', label = 'QSO')
plt.hist(new_frame['z'], bins = 'auto', label = 'elg', alpha = .5)

plt.ylabel('N(z)')
plt.xlabel('Redshift')
plt.legend()

# %% [markdown]
# # Adding Fluxes

# %% [markdown]
# Now we have to add the fluxes of the objects but only if the redshift is is less than the QSO

# %%
lense_qso = QSO_spec.sample(frac = .25)

# %%
lense_qso
# Out:
#                   targetid survey program  healpix         z  zwarn  \
# 352965   39633123184477457    sv3    dark     9830  1.148190      0
# 1719030  39628164472768801    sv1    dark     8769  0.866498      0
# 1296098    234551104241664    sv1   other    27257  1.107937      0
# 1963774  39632946780441822    sv3    dark     9337  1.791463      0
# 858706   39627261585921174    sv1    dark    21061  1.691983      0
# ...                    ...    ...     ...      ...       ...    ...
# 1196716  39627746128692426    sv3    dark    25932  1.635669      0
# 581471   39633318433524957    sv2    dark    11175  1.347668      0
# 698219   39633345679720700    sv2    dark     6004  1.698964      0
# 1063611  39627769675517405    sv3    dark    26275  0.890049      0
# 432988     103614244716628    sv1   other    11320  1.069316      4
#
#          coadd_fiberstatus spectype  mean_fiber_ra  mean_fiber_dec  \
# 352965                   0      QSO      239.99050       42.540028
# 1719030                  0      QSO      220.03665       15.637877
# 1296098                  0      QSO      151.27625        2.856538
# 1963774                  0      QSO      252.46654       33.356377
# 858706                   0      QSO       86.77956      -22.156006
# ...                    ...      ...            ...             ...
# 1196716                  0      QSO      219.30113       -1.755544
# 581471                   0      QSO      185.16180       54.656090
# 698219                   0      QSO      177.75565       56.676044
# 1063611                  0      QSO      182.88652       -0.763684
# 432988                   0      QSO      223.77097       50.431686
#
#          zcat_nspec  zcat_primary  desi_target      sv1_desi_target  \
# 352965            1             1            0                    0
# 1719030           1             1            0  4620974692658851844
# 1296098           1             1            0  4611686018427387904
# 1963774           1             1            0                    0
# 858706            1             1            0     9289498865185542
# ...             ...           ...          ...                  ...
# 1196716           1             1            0                    0
# 581471            1             1            0                    0
# 698219            1             1            0                    0
# 1063611           1             1            0                    0
# 432988            1             1            0  4611686018427387904
#
#              sv2_desi_target      sv3_desi_target
# 352965                     0                 1028
# 1719030                    0                    0
# 1296098                    0                    0
# 1963774                    0                 4674
# 858706                     0                    0
# ...                      ...                  ...
# 1196716                    0  4611686018427650052
# 581471                  1028                    0
# 698219   2305843009213694980                    0
# 1063611                    0  4611686018428829766
# 432988                     0                    0
#
# [11346 rows x 16 columns]

# %%
plt.hist(lense_qso['z'])
# Out:
# (array([ 280.,  497.,  585.,  955., 1248., 1348., 1467., 1534., 1740.,
#         1692.]),
#  array([0.50033743, 0.63029858, 0.76025973, 0.89022088, 1.02018203,
#         1.15014318, 1.28010433, 1.41006548, 1.54002662, 1.66998777,
#         1.79994892]),
#  <BarContainer object of 10 artists>)

# %%
lense_qso['z'].iloc[3798]
# Out:
# 1.6162464428677616

# %%
new_elg_dist = new_elg_sample.sample(frac=.25)

# %%
len(new_elg_dist), len(lense_qso)
# Out:
# (104117, 11346)

# %%
plt.hist(new_elg_dist['z'])
plt.hist(lense_qso['z'])
# Out:
# (array([ 280.,  497.,  585.,  955., 1248., 1348., 1467., 1534., 1740.,
#         1692.]),
#  array([0.50033743, 0.63029858, 0.76025973, 0.89022088, 1.02018203,
#         1.15014318, 1.28010433, 1.41006548, 1.54002662, 1.66998777,
#         1.79994892]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Creating the new table for lenses
#
# First we should define a function that retrieves the spectrum of that QSO if the redshift is less than the ELGs redshift

# %%
#function to create a table and create a panda table
def Spectrum_qso(jj):
    
    targetid_QSO = int(lense_qso['targetid'].iloc[jj])
    inc_qso = ['specid', 'redshift', 'flux', 'ivar', 'wavelength', 'spectype', 'specprimary', 'survey', 'program', 'targetid', 'coadd_fiberstatus']
    res_qso = client.retrieve_by_specid(specid_list = [targetid_QSO], include = inc_qso, dataset_list = ['DESI-EDR'])
    records_qso = res_qso.records

    ## Select the primary spectrum
    spec_primary_qso = np.array([records_qso[j].specprimary for j in range(len(records_qso))])
    primary_ii_qso = np.where(spec_primary_qso == True)[0][0]
    lam_primary_qso = np.asarray(records_qso[primary_ii_qso].wavelength)
    flam_primary_qso = np.asarray(records_qso[primary_ii_qso].flux)
    redshift_qso = np.asarray(records_qso[primary_ii_qso].redshift)
    
    table = pd.DataFrame({'Wavelength': lam_primary_qso, 'Flux': flam_primary_qso, 'Redshift':redshift_qso}, columns=['Wavelength', 'Flux', 'Redshift'])
    
    return(table)

# function for elg 
def Spectrum_elg(jj):
    
    targetid_elg = int(new_elg_dist['targetid'].iloc[jj])
    inc_elg = ['specid', 'redshift', 'flux', 'ivar', 'wavelength', 'spectype', 'specprimary', 'survey', 'program', 'targetid', 'coadd_fiberstatus']
    res_elg = client.retrieve_by_specid(specid_list = [targetid_elg], include = inc_elg, dataset_list = ['DESI-EDR'])
    records_elg = res_elg.records

    ## Select the primary spectrum
    spec_primary_elg = np.array([records_elg[j].specprimary for j in range(len(records_elg))])
    primary_ii_elg = np.where(spec_primary_elg == True)[0][0]
    lam_primary_elg = np.asarray(records_elg[primary_ii_elg].wavelength)
    flam_primary_elg = np.asarray(records_elg[primary_ii_elg].flux)
    redshift_elg = np.asarray(records_elg[primary_ii_elg].redshift)
    
    table_elg = pd.DataFrame({'Wavelength': lam_primary_elg, 'Flux': flam_primary_elg, 'Redshift':redshift_elg}, columns=['Wavelength', 'Flux', 'Redshift'])
    return(table_elg)

# function to add them
def Lensing(QSO, ELG):
    Flux_add = QSO['Flux'] + ELG['Flux']
    lam_primary_elg = ELG['Wavelength']
    table_lense = pd.DataFrame({'Wavelength': lam_primary_elg, 'Flux': Flux_add}, columns=['Wavelength', 'Flux'])
    return(table_lense)

# %%
# function to save them as a file

import os
import shutil


'''
First checks if the file path exists if it does it wipes out the folder and opens a new one.

Do this because if it runs with the products already in there 

the sample would be a result of a previous flux additions probably wich would probably go over the specified length.
'''

home = os.getcwd()
try:
    dir = os.listdir(home + '/TestingSample/')
except FileNotFoundError:
    os.mkdir('TestingSample')
else:
    shutil.rmtree(home + '/TestingSample')
    os.mkdir('TestingSample')
        
def save_file(file, index):
    '''
    Takes the table made from a previous cell and the 
    index of the elg to create a new file path
    
    '''
    home = os.getcwd()
    save = Table.from_pandas(file)
    new = save.write(home + '/TestingSample/' + str(lense_qso['targetid'].iloc[new_index]) + '+' + str(index) + '.fits')
    return(new)

# %% [markdown]
# We need to create a cell that runs through each row of the elgs <br/>
# and finds a qso from the table to add it to.
#
# Start with something basic that compares the redshift of the elg's to the qso (or vice versa).
#
# Note to self: You cannot use random.choice on an array you have to index the array first then randomly select the index

# %%
# simple test code to iterate through the elg table and find where QSO's are less than the selected elg's redshift at a certain index and then 
# randomly select from the list of indexes from np.where 
for i in range(0,2):
    locate_elg = new_elg_dist['z'].iloc[i]
    find_lowz_qso = np.where(lense_qso['z'] <= locate)
    row_to_column = np.transpose(find_lowz_qso)
    index_lowz = np.random.choice(len(row_to_column))
    new_index = int(row_to_column[index_lowz])
    higher_red = lense_qso['z'].iloc[new_index]
    
    QSO_Table = Spectrum_qso(new_index)
    ELG_table = Spectrum_elg(i)
    lense = Lensing(QSO_Table, ELG_table)
    index = new_elg_dist['targetid'].iloc[i]
    save_table = save_file(lense, index)

    print('QSO targetid is ', lense_qso['targetid'].iloc[new_index], "and the redshift is ", lense_qso['z'].iloc[new_index])
    print('ELG targetid is ', new_elg_dist['targetid'].iloc[i], "and the redshift is ", new_elg_dist['z'].iloc[i])
    
    plt.figure(figsize = (20, 6))
    plt.plot(lense['Wavelength'], convolve(lense['Flux'], Gaussian1DKernel(5)), color = 'k', lw = 2.0)
    plt.xlabel('$\lambda$ [$\AA$]')
    plt.ylabel('$F_{\lambda}$ [$10^{-17} erg\ s^{-1}\ cm^{-2}\ \AA^{-1}$]')
    plt.show()
# Out:
# /var/folders/p7/1jqm_mnx32q55mjfkdmwpm5h0000gn/T/ipykernel_2186/286701589.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   new_index = int(row_to_column[index_lowz])
# QSO targetid is  39633562894339390 and the redshift is  0.5885982163393042
# ELG targetid is  39633149709256488 and the redshift is  0.6717478979931679
# /var/folders/p7/1jqm_mnx32q55mjfkdmwpm5h0000gn/T/ipykernel_2186/286701589.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   new_index = int(row_to_column[index_lowz])
# QSO targetid is  39633453846627124 and the redshift is  0.5087830072577983
# ELG targetid is  39633118709153962 and the redshift is  0.6350279124346029

# %%
index
# Out:
# 39633149709256488
